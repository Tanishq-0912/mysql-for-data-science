# %% [raw]
# PyMySQL is an interface for connecting to a MySQL database server from Python. It implements the Python Database API v2. 0 and contains a pure-Python MySQL client library. The goal of PyMySQL is to be a drop-in replacement for MySQLdb.

# %%
# !pip install pymysql
# !pip install mysql-connector
# Out:
# Requirement already satisfied: mysql-connector in c:\users\admin\anaconda3\lib\site-packages (2.2.9)

# %%
pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.2.0-cp312-cp312-win_amd64.whl.metadata (6.2 kB)
# Downloading mysql_connector_python-9.2.0-cp312-cp312-win_amd64.whl (16.1 MB)
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/16.1 MB 6.3 MB/s eta 0:00:03
#    ----- ---------------------------------- 2.4/16.1 MB 5.8 MB/s eta 0:00:03
#    ------- -------------------------------- 3.1/16.1 MB 5.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 4.2/16.1 MB 5.2 MB/s eta 0:00:03
#    ------------ --------------------------- 5.0/16.1 MB 4.9 MB/s eta 0:00:03
#    -------------- ------------------------- 5.8/16.1 MB 4.8 MB/s eta 0:00:03
#    --------------- ------------------------ 6.3/16.1 MB 4.6 MB/s eta 0:00:03
#    ----------------- ---------------------- 7.1/16.1 MB 4.4 MB/s eta 0:00:03
#    ------------------- -------------------- 7.9/16.1 MB 4.2 MB/s eta 0:00:02
#    -------------------- ------------------- 8.1/16.1 MB 4.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 8.9/16.1 MB 3.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 9.4/16.1 MB 3.8 MB/s eta 0:00:02
#    ------------------------ --------------- 10.0/16.1 MB 3.7 MB/s eta 0:00:02
#    -------------------------- ------------- 10.5/16.1 MB 3.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 11.3/16.1 MB 3.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.8/16.1 MB 3.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 12.1/16.1 MB 3.4 MB/s eta 0:00:02
#    ------------------------------- -------- 12.6/16.1 MB 3.3 MB/s eta 0:00:02
#    -------------------------------- ------- 13.1/16.1 MB 3.2 MB/s eta 0:00:01
#    --------------------------------- ------ 13.6/16.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.9/16.1 MB 3.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.2/16.1 MB 3.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.4/16.1 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------- -- 14.9/16.1 MB 2.9 MB/s eta 0:00:01
#    -------------------------------------- - 15.5/16.1 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  15.7/16.1 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  16.0/16.1 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  16.0/16.1 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 16.1/16.1 MB 2.6 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import mysql.connector
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
## making connections to database server
connection=mysql.connector.connect(host = '18.136.157.135',user='dm_user_sql',
                                  password='37z49REb$nK@nlpV!vJ')

# %%
## Check the number of databases available on the server
cursor=connection.cursor()
cursor.execute('show databases')
for i in cursor:
    print(i)
# Out:
# ('information_schema',)
# ('datamites_sql',)

# %%
## connecting the database
connection=mysql.connector.connect(host='18.136.157.135',
                                  user='dm_user_sql',
                                  password='37z49REb$nK@nlpV!vJ',
                                  database='datamites_sql')

# %%
db_tables=pd.read_sql_query('show tables',connection)
print(db_tables)
# Out:
#   Tables_in_datamites_sql
# 0                 Country
# 1               customers
# 2                    dept
# 3                     emp
# 4                  orders
# 5                products
# 6                salgrade

# %%
df=pd.read_sql_query("select * from emp",connection)
df
# Out:
#     empno   ename        job     mgr    hiredate     sal    comm  deptno
# 0    7369   SMITH      CLERK  7902.0  1993-06-13   800.0     0.0      20
# 1    7499   ALLEN   SALESMAN  7698.0  1998-08-15  1600.0   300.0      30
# 2    7521    WARD   SALESMAN  7698.0  1996-03-26  1250.0   500.0      30
# 3    7566   JONES    MANAGER  7839.0  1995-10-31  2975.0     NaN      20
# 4    7654  MARTIN   SALESMAN  7698.0  1998-12-05  1250.0  1400.0      30
# 5    7698   BLAKE    MANAGER  7839.0  1992-06-11  2850.0     NaN      30
# 6    7782   CLARK    MANAGER  7839.0  1993-05-14  2450.0     NaN      10
# 7    7788   SCOTT    ANALYST  7566.0  1996-03-05  3000.0     NaN      20
# 8    7839    KING  PRESIDENT     NaN  1990-06-09  5000.0     0.0      10
# 9    7844  TURNER   SALESMAN  7698.0  1995-06-04  1500.0     0.0      30
# 10   7876   ADAMS      CLERK  7788.0  1999-06-04  1100.0     NaN      20
# 11   7900   JAMES      CLERK  7698.0  2000-06-23   950.0     NaN      30
# 12   7902    FORD    ANALYST  7566.0  1997-12-05  3000.0     NaN      20
# 13   7934  MILLER      CLERK  7782.0  2000-01-21  1300.0     NaN      10

# %%
df.to_csv("tp.csv")

# %%
a=input("Enter a letter")
query="select * from emp where ename like '%{}'"
pd.read_sql_query(query.format(a),connection)
# Out:
# Enter a letter t
#    empno  ename      job   mgr    hiredate     sal  comm  deptno
# 0   7788  SCOTT  ANALYST  7566  1996-03-05  3000.0  None      20

# %%
query = "select * from orders"
output = pd.read_sql(query,connection)
print(output.shape)
output
# Out:
# (9, 6)
#          order_id  order_date customer_id       product_id   sales  quantity
# 0  CA-2015-115812    6/9/2015    BH-11710  FUR-FU-10001487  48.860         7
# 1  CA-2017-105654  12/10/2017    BH-11710  FUR-TA-10000577  71.530         3
# 2  CA-2017-138688   6/12/2017    DV-13045  OFF-LA-10000240  14.620         2
# 3  CA-2017-152156   11/8/2017    CG-12520  FUR-BO-10001798  58.960         2
# 4  CA-2018-109265    2/8/2018    BH-11710  OFF-LA-10000240  14.620         5
# 5  CA-2018-109862    4/9/2018    DV-13045  OFF-PA-10002365  15.552         1
# 6  CA-2018-112417    6/8/2018    SO-20335  OFF-PA-10002365  15.552         2
# 7  CA-2018-114412   4/11/2018    AA-10480  OFF-PA-10002365  15.552         3
# 8  US-2016-108966  10/11/2017    SO-20335  FUR-TA-10000577  69.650         5

# %%
query = "select * from emp" # SQL statement
output = pd.read_sql(query,connection)
print(output.shape)
output
# Out:
# (14, 8)
#     empno   ename        job     mgr    hiredate     sal    comm  deptno
# 0    7369   SMITH      CLERK  7902.0  1993-06-13   800.0     0.0      20
# 1    7499   ALLEN   SALESMAN  7698.0  1998-08-15  1600.0   300.0      30
# 2    7521    WARD   SALESMAN  7698.0  1996-03-26  1250.0   500.0      30
# 3    7566   JONES    MANAGER  7839.0  1995-10-31  2975.0     NaN      20
# 4    7654  MARTIN   SALESMAN  7698.0  1998-12-05  1250.0  1400.0      30
# 5    7698   BLAKE    MANAGER  7839.0  1992-06-11  2850.0     NaN      30
# 6    7782   CLARK    MANAGER  7839.0  1993-05-14  2450.0     NaN      10
# 7    7788   SCOTT    ANALYST  7566.0  1996-03-05  3000.0     NaN      20
# 8    7839    KING  PRESIDENT     NaN  1990-06-09  5000.0     0.0      10
# 9    7844  TURNER   SALESMAN  7698.0  1995-06-04  1500.0     0.0      30
# 10   7876   ADAMS      CLERK  7788.0  1999-06-04  1100.0     NaN      20
# 11   7900   JAMES      CLERK  7698.0  2000-06-23   950.0     NaN      30
# 12   7902    FORD    ANALYST  7566.0  1997-12-05  3000.0     NaN      20
# 13   7934  MILLER      CLERK  7782.0  2000-01-21  1300.0     NaN      10

# %%
# Task:-get details of products table

# %%
query = "select * from products"
output = pd.read_sql(query,connection)
print(output.shape)
output
# Out:
# (14, 4)
#          product_id         category sub_category  \
# 0   FUR-BO-10001798        Furniture    Bookcases
# 1   FUR-CH-10000454        Furniture       Chairs
# 2   FUR-FU-10001487        Furniture  Furnishings
# 3   FUR-TA-10000577        Furniture       Tables
# 4   FUR-TA-10001539        Furniture       Tables
# 5   OFF-AP-10002892  Office Supplies   Appliances
# 6   OFF-AR-10002833  Office Supplies          Art
# 7   OFF-BI-10003656  Office Supplies      Binders
# 8   OFF-BI-10003910  Office Supplies      Binders
# 9   OFF-LA-10000240  Office Supplies       Labels
# 10  OFF-PA-10002365  Office Supplies        Paper
# 11  OFF-ST-10000760  Office Supplies      Storage
# 12  TEC-PH-10002033       Technology       Phones
# 13  TEC-PH-10002275       Technology       Phones
#
#                                          product_name
# 0                   Bush Somerset Collection Bookcase
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2   Eldon Expressions Wood and Plastic Desk Access...
# 3       Bretford CR4500 Series Slim Rectangular Table
# 4            Chromcraft Rectangular Conference Tables
# 5                    Belkin F5C206VTEL 6 Outlet Surge
# 6                                          Newell 322
# 7         Fellowes PB200 Plastic Comb Binding Machine
# 8   DXL Angle-View Binders with Locking Rings by S...
# 9   Self-Adhesive Address Labels for Typewriters b...
# 10                                         Xerox 1967
# 11                     Eldon Fold 'N Roll Cart System
# 12    Konftel 250 ConferenceÂ phoneÂ - Charcoal black
# 13                     Mitel 5320 IP Phone VoIP phone

# %%
query =

# %% [markdown]
# # SQL Where Condition

# %%
query="select * from emp where job='SALESMAN'"
data=pd.read_sql(query,connection)
print(data)
# Out:
#    empno   ename       job   mgr    hiredate     sal    comm  deptno
# 0   7499   ALLEN  SALESMAN  7698  1998-08-15  1600.0   300.0      30
# 1   7521    WARD  SALESMAN  7698  1996-03-26  1250.0   500.0      30
# 2   7654  MARTIN  SALESMAN  7698  1998-12-05  1250.0  1400.0      30
# 3   7844  TURNER  SALESMAN  7698  1995-06-04  1500.0     0.0      30

# %%
query="select * from products"
data=pd.read_sql(query,connection)
data
# Out:
#          product_id         category sub_category  \
# 0   FUR-BO-10001798        Furniture    Bookcases
# 1   FUR-CH-10000454        Furniture       Chairs
# 2   FUR-FU-10001487        Furniture  Furnishings
# 3   FUR-TA-10000577        Furniture       Tables
# 4   FUR-TA-10001539        Furniture       Tables
# 5   OFF-AP-10002892  Office Supplies   Appliances
# 6   OFF-AR-10002833  Office Supplies          Art
# 7   OFF-BI-10003656  Office Supplies      Binders
# 8   OFF-BI-10003910  Office Supplies      Binders
# 9   OFF-LA-10000240  Office Supplies       Labels
# 10  OFF-PA-10002365  Office Supplies        Paper
# 11  OFF-ST-10000760  Office Supplies      Storage
# 12  TEC-PH-10002033       Technology       Phones
# 13  TEC-PH-10002275       Technology       Phones
#
#                                          product_name
# 0                   Bush Somerset Collection Bookcase
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2   Eldon Expressions Wood and Plastic Desk Access...
# 3       Bretford CR4500 Series Slim Rectangular Table
# 4            Chromcraft Rectangular Conference Tables
# 5                    Belkin F5C206VTEL 6 Outlet Surge
# 6                                          Newell 322
# 7         Fellowes PB200 Plastic Comb Binding Machine
# 8   DXL Angle-View Binders with Locking Rings by S...
# 9   Self-Adhesive Address Labels for Typewriters b...
# 10                                         Xerox 1967
# 11                     Eldon Fold 'N Roll Cart System
# 12    Konftel 250 ConferenceÂ phoneÂ - Charcoal black
# 13                     Mitel 5320 IP Phone VoIP phone

# %%
query = "select * from products where category='Furniture'"
products = pd.read_sql(query,connection)
print(products.shape)
products
# Out:
# (5, 4)
#         product_id   category sub_category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
# 2  FUR-FU-10001487  Furniture  Furnishings
# 3  FUR-TA-10000577  Furniture       Tables
# 4  FUR-TA-10001539  Furniture       Tables
#
#                                         product_name
# 0                  Bush Somerset Collection Bookcase
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2  Eldon Expressions Wood and Plastic Desk Access...
# 3      Bretford CR4500 Series Slim Rectangular Table
# 4           Chromcraft Rectangular Conference Tables

# %%
query = "select * from emp where job='MANAGER'"
products = pd.read_sql(query,connection)
print(products.shape)
products
# Out:
# (3, 8)
#    empno  ename      job   mgr    hiredate     sal  comm  deptno
# 0   7566  JONES  MANAGER  7839  1995-10-31  2975.0  None      20
# 1   7698  BLAKE  MANAGER  7839  1992-06-11  2850.0  None      30
# 2   7782  CLARK  MANAGER  7839  1993-05-14  2450.0  None      10

# %%
# to retrive specific columns from given table
query = "select ename,empno from emp where job='MANAGER'"
products = pd.read_sql(query,connection)
print(products.shape)
products
# Out:
# (3, 2)
#    ename  empno
# 0  JONES   7566
# 1  BLAKE   7698
# 2  CLARK   7782

# %%
# Distinct keyword helps in getting unique values of the column
query = "SELECT DISTINCT job FROM emp"
output = pd.read_sql(query,connection)
output
# Out:
#          job
# 0      CLERK
# 1   SALESMAN
# 2    MANAGER
# 3    ANALYST
# 4  PRESIDENT

# %%
## count helps in counting the rows
query = "SELECT count(job) FROM emp"
output = pd.read_sql(query,connection)
output
# Out:
#    count(job)
# 0          14

# %% [markdown]
# # SQL Where Condition and logical statement

# %%
query = "select * from products where category='Furniture' or category='Technology'"
products = pd.read_sql(query,connection)
print(products.shape)
products
# Out:
# (7, 4)
#         product_id    category sub_category  \
# 0  FUR-BO-10001798   Furniture    Bookcases
# 1  FUR-CH-10000454   Furniture       Chairs
# 2  FUR-FU-10001487   Furniture  Furnishings
# 3  FUR-TA-10000577   Furniture       Tables
# 4  FUR-TA-10001539   Furniture       Tables
# 5  TEC-PH-10002033  Technology       Phones
# 6  TEC-PH-10002275  Technology       Phones
#
#                                         product_name
# 0                  Bush Somerset Collection Bookcase
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2  Eldon Expressions Wood and Plastic Desk Access...
# 3      Bretford CR4500 Series Slim Rectangular Table
# 4           Chromcraft Rectangular Conference Tables
# 5    Konftel 250 ConferenceÂ phoneÂ - Charcoal black
# 6                     Mitel 5320 IP Phone VoIP phone

# %%
query = "select * from products where category='Furniture' and sub_category='Chairs'"
products = pd.read_sql(query,connection)
print(products.shape)
products
# Out:
# (1, 4)
#         product_id   category sub_category  \
# 0  FUR-CH-10000454  Furniture       Chairs
#
#                                         product_name
# 0  Hon Deluxe Fabric Upholstered Stacking Chairs,...

# %%
query= "select count(sub_category),category from   products  group by category"
data = pd.read_sql(query,connection)
data
# Out:
#    count(sub_category)         category
# 0                    5        Furniture
# 1                    7  Office Supplies
# 2                    2       Technology

# %%
#Retrieve all data from products where categorgy is Office Supplies and sub-categorgy is Binders
query = "select * from products where category='Office Supplies' and sub_category='Binders'"
products = pd.read_sql(query,connection)
print(products.shape)
products
# Out:
# (2, 4)
#         product_id         category sub_category  \
# 0  OFF-BI-10003656  Office Supplies      Binders
# 1  OFF-BI-10003910  Office Supplies      Binders
#
#                                         product_name
# 0        Fellowes PB200 Plastic Comb Binding Machine
# 1  DXL Angle-View Binders with Locking Rings by S...

# %%
query = "select * from products where category='Office Supplies' or sub_category='Binders'"
products = pd.read_sql(query,connection)
print(products.shape)
products
# Out:
# (7, 4)
#         product_id         category sub_category  \
# 0  OFF-AP-10002892  Office Supplies   Appliances
# 1  OFF-AR-10002833  Office Supplies          Art
# 2  OFF-BI-10003656  Office Supplies      Binders
# 3  OFF-BI-10003910  Office Supplies      Binders
# 4  OFF-LA-10000240  Office Supplies       Labels
# 5  OFF-PA-10002365  Office Supplies        Paper
# 6  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name
# 0                   Belkin F5C206VTEL 6 Outlet Surge
# 1                                         Newell 322
# 2        Fellowes PB200 Plastic Comb Binding Machine
# 3  DXL Angle-View Binders with Locking Rings by S...
# 4  Self-Adhesive Address Labels for Typewriters b...
# 5                                         Xerox 1967
# 6                     Eldon Fold 'N Roll Cart System

# %% [markdown]
# # SQL order by clause

# %%
query = "SELECT * FROM emp order by sal"
output = pd.read_sql(query,connection)
output
# Out:
#     empno   ename        job     mgr    hiredate     sal    comm  deptno
# 0    7369   SMITH      CLERK  7902.0  1993-06-13   800.0     0.0      20
# 1    7900   JAMES      CLERK  7698.0  2000-06-23   950.0     NaN      30
# 2    7876   ADAMS      CLERK  7788.0  1999-06-04  1100.0     NaN      20
# 3    7521    WARD   SALESMAN  7698.0  1996-03-26  1250.0   500.0      30
# 4    7654  MARTIN   SALESMAN  7698.0  1998-12-05  1250.0  1400.0      30
# 5    7934  MILLER      CLERK  7782.0  2000-01-21  1300.0     NaN      10
# 6    7844  TURNER   SALESMAN  7698.0  1995-06-04  1500.0     0.0      30
# 7    7499   ALLEN   SALESMAN  7698.0  1998-08-15  1600.0   300.0      30
# 8    7782   CLARK    MANAGER  7839.0  1993-05-14  2450.0     NaN      10
# 9    7698   BLAKE    MANAGER  7839.0  1992-06-11  2850.0     NaN      30
# 10   7566   JONES    MANAGER  7839.0  1995-10-31  2975.0     NaN      20
# 11   7788   SCOTT    ANALYST  7566.0  1996-03-05  3000.0     NaN      20
# 12   7902    FORD    ANALYST  7566.0  1997-12-05  3000.0     NaN      20
# 13   7839    KING  PRESIDENT     NaN  1990-06-09  5000.0     0.0      10

# %%
query = "SELECT * FROM emp order by sal desc"
output = pd.read_sql(query,connection)
output
# Out:
#     empno   ename        job     mgr    hiredate     sal    comm  deptno
# 0    7839    KING  PRESIDENT     NaN  1990-06-09  5000.0     0.0      10
# 1    7788   SCOTT    ANALYST  7566.0  1996-03-05  3000.0     NaN      20
# 2    7902    FORD    ANALYST  7566.0  1997-12-05  3000.0     NaN      20
# 3    7566   JONES    MANAGER  7839.0  1995-10-31  2975.0     NaN      20
# 4    7698   BLAKE    MANAGER  7839.0  1992-06-11  2850.0     NaN      30
# 5    7782   CLARK    MANAGER  7839.0  1993-05-14  2450.0     NaN      10
# 6    7499   ALLEN   SALESMAN  7698.0  1998-08-15  1600.0   300.0      30
# 7    7844  TURNER   SALESMAN  7698.0  1995-06-04  1500.0     0.0      30
# 8    7934  MILLER      CLERK  7782.0  2000-01-21  1300.0     NaN      10
# 9    7521    WARD   SALESMAN  7698.0  1996-03-26  1250.0   500.0      30
# 10   7654  MARTIN   SALESMAN  7698.0  1998-12-05  1250.0  1400.0      30
# 11   7876   ADAMS      CLERK  7788.0  1999-06-04  1100.0     NaN      20
# 12   7900   JAMES      CLERK  7698.0  2000-06-23   950.0     NaN      30
# 13   7369   SMITH      CLERK  7902.0  1993-06-13   800.0     0.0      20

# %%
query = "SELECT * FROM emp order by sal,deptno"
output = pd.read_sql(query,connection)
output
# Out:
#     empno   ename        job     mgr    hiredate     sal    comm  deptno
# 0    7369   SMITH      CLERK  7902.0  1993-06-13   800.0     0.0      20
# 1    7900   JAMES      CLERK  7698.0  2000-06-23   950.0     NaN      30
# 2    7876   ADAMS      CLERK  7788.0  1999-06-04  1100.0     NaN      20
# 3    7521    WARD   SALESMAN  7698.0  1996-03-26  1250.0   500.0      30
# 4    7654  MARTIN   SALESMAN  7698.0  1998-12-05  1250.0  1400.0      30
# 5    7934  MILLER      CLERK  7782.0  2000-01-21  1300.0     NaN      10
# 6    7844  TURNER   SALESMAN  7698.0  1995-06-04  1500.0     0.0      30
# 7    7499   ALLEN   SALESMAN  7698.0  1998-08-15  1600.0   300.0      30
# 8    7782   CLARK    MANAGER  7839.0  1993-05-14  2450.0     NaN      10
# 9    7698   BLAKE    MANAGER  7839.0  1992-06-11  2850.0     NaN      30
# 10   7566   JONES    MANAGER  7839.0  1995-10-31  2975.0     NaN      20
# 11   7788   SCOTT    ANALYST  7566.0  1996-03-05  3000.0     NaN      20
# 12   7902    FORD    ANALYST  7566.0  1997-12-05  3000.0     NaN      20
# 13   7839    KING  PRESIDENT     NaN  1990-06-09  5000.0     0.0      10

# %% [markdown]
# # SQL NULL Values

# %%
query = "SELECT * FROM emp where comm is null "
output = pd.read_sql(query,connection)
output
# Out:
#    empno   ename      job   mgr    hiredate     sal  comm  deptno
# 0   7566   JONES  MANAGER  7839  1995-10-31  2975.0  None      20
# 1   7698   BLAKE  MANAGER  7839  1992-06-11  2850.0  None      30
# 2   7782   CLARK  MANAGER  7839  1993-05-14  2450.0  None      10
# 3   7788   SCOTT  ANALYST  7566  1996-03-05  3000.0  None      20
# 4   7876   ADAMS    CLERK  7788  1999-06-04  1100.0  None      20
# 5   7900   JAMES    CLERK  7698  2000-06-23   950.0  None      30
# 6   7902    FORD  ANALYST  7566  1997-12-05  3000.0  None      20
# 7   7934  MILLER    CLERK  7782  2000-01-21  1300.0  None      10

# %%
query = "SELECT * FROM emp where comm is not null "
output = pd.read_sql(query,connection)
output
# Out:
#    empno   ename        job     mgr    hiredate     sal    comm  deptno
# 0   7369   SMITH      CLERK  7902.0  1993-06-13   800.0     0.0      20
# 1   7499   ALLEN   SALESMAN  7698.0  1998-08-15  1600.0   300.0      30
# 2   7521    WARD   SALESMAN  7698.0  1996-03-26  1250.0   500.0      30
# 3   7654  MARTIN   SALESMAN  7698.0  1998-12-05  1250.0  1400.0      30
# 4   7839    KING  PRESIDENT     NaN  1990-06-09  5000.0     0.0      10
# 5   7844  TURNER   SALESMAN  7698.0  1995-06-04  1500.0     0.0      30

# %% [markdown]
# # SQL Aggregation

# %%
query = "SELECT min(sal) FROM emp where comm is not null "
output = pd.read_sql(query,connection)
output
# Out:
#    min(sal)
# 0     800.0

# %%
query = "SELECT max(sal) FROM emp where comm is not null "
output = pd.read_sql(query,connection)
output
# Out:
#    max(sal)
# 0    5000.0

# %%
query = "SELECT avg(sal) FROM emp where comm is not null "
output = pd.read_sql(query,connection)
output
# Out:
#    avg(sal)
# 0    1900.0

# %% [markdown]
# # SQL Like operator

# %% [raw]
# WHERE CustomerName LIKE 'a%'	Finds any values that start with "a"
# WHERE CustomerName LIKE '%a'	Finds any values that end with "a"
# WHERE CustomerName LIKE '%or%'	Finds any values that have "or" in any position
# WHERE CustomerName LIKE '_r%'	Finds any values that have "r" in the second position
# WHERE CustomerName LIKE 'a_%'	Finds any values that start with "a" and are at least 2 characters in length
# WHERE CustomerName LIKE 'a__%'	Finds any values that start with "a" and are at least 3 characters in length
# WHERE ContactName LIKE 'a%o'	Finds any values that start with "a" and ends with "o"

# %%
query = "SELECT  * FROM emp "
output = pd.read_sql(query,connection)
output
# Out:
#     empno   ename        job     mgr    hiredate     sal    comm  deptno
# 0    7369   SMITH      CLERK  7902.0  1993-06-13   800.0     0.0      20
# 1    7499   ALLEN   SALESMAN  7698.0  1998-08-15  1600.0   300.0      30
# 2    7521    WARD   SALESMAN  7698.0  1996-03-26  1250.0   500.0      30
# 3    7566   JONES    MANAGER  7839.0  1995-10-31  2975.0     NaN      20
# 4    7654  MARTIN   SALESMAN  7698.0  1998-12-05  1250.0  1400.0      30
# 5    7698   BLAKE    MANAGER  7839.0  1992-06-11  2850.0     NaN      30
# 6    7782   CLARK    MANAGER  7839.0  1993-05-14  2450.0     NaN      10
# 7    7788   SCOTT    ANALYST  7566.0  1996-03-05  3000.0     NaN      20
# 8    7839    KING  PRESIDENT     NaN  1990-06-09  5000.0     0.0      10
# 9    7844  TURNER   SALESMAN  7698.0  1995-06-04  1500.0     0.0      30
# 10   7876   ADAMS      CLERK  7788.0  1999-06-04  1100.0     NaN      20
# 11   7900   JAMES      CLERK  7698.0  2000-06-23   950.0     NaN      30
# 12   7902    FORD    ANALYST  7566.0  1997-12-05  3000.0     NaN      20
# 13   7934  MILLER      CLERK  7782.0  2000-01-21  1300.0     NaN      10

# %%
query = "SELECT  * FROM emp where ename like '%r' "
output = pd.read_sql(query,connection)
output
# Out:
#    empno   ename       job   mgr    hiredate     sal  comm  deptno
# 0   7844  TURNER  SALESMAN  7698  1995-06-04  1500.0   0.0      30
# 1   7934  MILLER     CLERK  7782  2000-01-21  1300.0   NaN      10

# %%
query = "SELECT  * FROM emp where ename like 'S%' "
output = pd.read_sql(query,connection)
output
# Out:
#    empno  ename      job   mgr    hiredate     sal  comm  deptno
# 0   7369  SMITH    CLERK  7902  1993-06-13   800.0   0.0      20
# 1   7788  SCOTT  ANALYST  7566  1996-03-05  3000.0   NaN      20

# %% [markdown]
# # SQL IN operator

# %%
query = "SELECT  * FROM dept where dname in('Accounting','Operations') "
output = pd.read_sql(query,connection)
output
# Out:
#    deptno       dname  location
# 0      10  Accounting  New York
# 1      40  Operations    Boston

# %%
query = "select * from dept"
output = pd.read_sql(query,connection)
print(output.shape)
output
# Out:
# (4, 3)
#    deptno       dname  location
# 0      10  Accounting  New York
# 1      20    Research    Dallas
# 2      30       Sales   Chicago
# 3      40  Operations    Boston

# %% [markdown]
# # SQL Between operator

# %%
query = "SELECT  * FROM emp where sal between 800.0 and 1600.0 "
output = pd.read_sql(query,connection)
output
# Out:
#    empno   ename       job   mgr    hiredate     sal    comm  deptno
# 0   7369   SMITH     CLERK  7902  1993-06-13   800.0     0.0      20
# 1   7499   ALLEN  SALESMAN  7698  1998-08-15  1600.0   300.0      30
# 2   7521    WARD  SALESMAN  7698  1996-03-26  1250.0   500.0      30
# 3   7654  MARTIN  SALESMAN  7698  1998-12-05  1250.0  1400.0      30
# 4   7844  TURNER  SALESMAN  7698  1995-06-04  1500.0     0.0      30
# 5   7876   ADAMS     CLERK  7788  1999-06-04  1100.0     NaN      20
# 6   7900   JAMES     CLERK  7698  2000-06-23   950.0     NaN      30
# 7   7934  MILLER     CLERK  7782  2000-01-21  1300.0     NaN      10

# %% [markdown]
# # SQL Joins
# * (INNER) JOIN: Returns records that have matching values in both tables.
#
# * LEFT (OUTER) JOIN: Returns all records from the left table, and the matched records from the right table.
#
# * RIGHT (OUTER) JOIN: Returns all records from the right table, and the matched records from the left table

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## SQL Left Join
# also called as Left Outer Join
# * INNER JOIN - Matched rows from two tables
#
# * LEFT OUTER join includes unmatched rows from the left table + matched rows, while RIGHT OUTER join includes unmatched rows from the right side of the table + matched rows.
#
# * The result of LEFT OUTER join can be seen as INNER JOIN + unmatched rows of left table while the result of the RIGHT OUTER join is equal to INNER JOIN + unmatched rows from the right side table.

# %%
query = "select * from customers  left join orders on orders.customer_id=customers.customer_id"
data = pd.read_sql(query,connection)
print(data.shape)
data
# Out:
# (14, 11)
#    customer_id       customer_name             city           state  \
# 0     BH-11710     Brosina Hoffman      Los Angeles      California
# 1     BH-11710     Brosina Hoffman      Los Angeles      California
# 2     DV-13045     Darrin Van Huff      Los Angeles      California
# 3     CG-12520         Claire Gute        Henderson        Kentucky
# 4     BH-11710     Brosina Hoffman      Los Angeles      California
# 5     DV-13045     Darrin Van Huff      Los Angeles      California
# 6     SO-20335      Sean O'Donnell  Fort Lauderdale         Florida
# 7     AA-10480        Andrew Allen          Concord  North Carolina
# 8     SO-20335      Sean O'Donnell  Fort Lauderdale         Florida
# 9     AG-10270     Alejandro Grove      West Jordan            Utah
# 10    HP-14815       Harold Pawlan       Fort Worth           Texas
# 11    IM-15070        Irene Maddox          Seattle      Washington
# 12    PK-19075           Pete Kriz          Madison       Wisconsin
# 13    ZD-21925  Zuschuss Donatelli    San Francisco      California
#
#     postal_code        order_id  order_date customer_id       product_id  \
# 0         90032  CA-2015-115812    6/9/2015    BH-11710  FUR-FU-10001487
# 1         90032  CA-2017-105654  12/10/2017    BH-11710  FUR-TA-10000577
# 2         90036  CA-2017-138688   6/12/2017    DV-13045  OFF-LA-10000240
# 3         42420  CA-2017-152156   11/8/2017    CG-12520  FUR-BO-10001798
# 4         90032  CA-2018-109265    2/8/2018    BH-11710  OFF-LA-10000240
# 5         90036  CA-2018-109862    4/9/2018    DV-13045  OFF-PA-10002365
# 6         33311  CA-2018-112417    6/8/2018    SO-20335  OFF-PA-10002365
# 7         28027  CA-2018-114412   4/11/2018    AA-10480  OFF-PA-10002365
# 8         33311  US-2016-108966  10/11/2017    SO-20335  FUR-TA-10000577
# 9         84084            None        None        None             None
# 10        76106            None        None        None             None
# 11        98103            None        None        None             None
# 12        53711            None        None        None             None
# 13        94109            None        None        None             None
#
#      sales  quantity
# 0   48.860       7.0
# 1   71.530       3.0
# 2   14.620       2.0
# 3   58.960       2.0
# 4   14.620       5.0
# 5   15.552       1.0
# 6   15.552       2.0
# 7   15.552       3.0
# 8   69.650       5.0
# 9      NaN       NaN
# 10     NaN       NaN
# 11     NaN       NaN
# 12     NaN       NaN
# 13     NaN       NaN

# %%
query = "select order_id from orders  left join customers on orders.customer_id=customers.customer_id"
data = pd.read_sql(query,connection)
print(data.shape)
data
# Out:
# (9, 1)
#          order_id
# 0  CA-2015-115812
# 1  CA-2017-105654
# 2  CA-2017-138688
# 3  CA-2017-152156
# 4  CA-2018-109265
# 5  CA-2018-109862
# 6  CA-2018-112417
# 7  CA-2018-114412
# 8  US-2016-108966

# %% [markdown]
# ## SQL Right Join
# Also called as Right outer join

# %%
query = "select * from customers  right join orders on orders.customer_id=customers.customer_id"
data = pd.read_sql(query,connection)
print(data.shape)
data
# Out:
# (9, 11)
#   customer_id    customer_name             city           state  postal_code  \
# 0    BH-11710  Brosina Hoffman      Los Angeles      California        90032
# 1    BH-11710  Brosina Hoffman      Los Angeles      California        90032
# 2    DV-13045  Darrin Van Huff      Los Angeles      California        90036
# 3    CG-12520      Claire Gute        Henderson        Kentucky        42420
# 4    BH-11710  Brosina Hoffman      Los Angeles      California        90032
# 5    DV-13045  Darrin Van Huff      Los Angeles      California        90036
# 6    SO-20335   Sean O'Donnell  Fort Lauderdale         Florida        33311
# 7    AA-10480     Andrew Allen          Concord  North Carolina        28027
# 8    SO-20335   Sean O'Donnell  Fort Lauderdale         Florida        33311
#
#          order_id  order_date customer_id       product_id   sales  quantity
# 0  CA-2015-115812    6/9/2015    BH-11710  FUR-FU-10001487  48.860         7
# 1  CA-2017-105654  12/10/2017    BH-11710  FUR-TA-10000577  71.530         3
# 2  CA-2017-138688   6/12/2017    DV-13045  OFF-LA-10000240  14.620         2
# 3  CA-2017-152156   11/8/2017    CG-12520  FUR-BO-10001798  58.960         2
# 4  CA-2018-109265    2/8/2018    BH-11710  OFF-LA-10000240  14.620         5
# 5  CA-2018-109862    4/9/2018    DV-13045  OFF-PA-10002365  15.552         1
# 6  CA-2018-112417    6/8/2018    SO-20335  OFF-PA-10002365  15.552         2
# 7  CA-2018-114412   4/11/2018    AA-10480  OFF-PA-10002365  15.552         3
# 8  US-2016-108966  10/11/2017    SO-20335  FUR-TA-10000577  69.650         5

# %%
# fechting only customers details who have orders
query = "select * from customers  right join orders on orders.customer_id=customers.customer_id"
data = pd.read_sql(query,connection)
print(data.shape)
data
# Out:
# (9, 11)
#   customer_id    customer_name             city           state  postal_code  \
# 0    BH-11710  Brosina Hoffman      Los Angeles      California        90032
# 1    BH-11710  Brosina Hoffman      Los Angeles      California        90032
# 2    DV-13045  Darrin Van Huff      Los Angeles      California        90036
# 3    CG-12520      Claire Gute        Henderson        Kentucky        42420
# 4    BH-11710  Brosina Hoffman      Los Angeles      California        90032
# 5    DV-13045  Darrin Van Huff      Los Angeles      California        90036
# 6    SO-20335   Sean O'Donnell  Fort Lauderdale         Florida        33311
# 7    AA-10480     Andrew Allen          Concord  North Carolina        28027
# 8    SO-20335   Sean O'Donnell  Fort Lauderdale         Florida        33311
#
#          order_id  order_date customer_id       product_id   sales  quantity
# 0  CA-2015-115812    6/9/2015    BH-11710  FUR-FU-10001487  48.860         7
# 1  CA-2017-105654  12/10/2017    BH-11710  FUR-TA-10000577  71.530         3
# 2  CA-2017-138688   6/12/2017    DV-13045  OFF-LA-10000240  14.620         2
# 3  CA-2017-152156   11/8/2017    CG-12520  FUR-BO-10001798  58.960         2
# 4  CA-2018-109265    2/8/2018    BH-11710  OFF-LA-10000240  14.620         5
# 5  CA-2018-109862    4/9/2018    DV-13045  OFF-PA-10002365  15.552         1
# 6  CA-2018-112417    6/8/2018    SO-20335  OFF-PA-10002365  15.552         2
# 7  CA-2018-114412   4/11/2018    AA-10480  OFF-PA-10002365  15.552         3
# 8  US-2016-108966  10/11/2017    SO-20335  FUR-TA-10000577  69.650         5

# %% [markdown]
# ## SQL Inner Join
# This is default

# %%
query = "select * from customers " # SQL statement
output = pd.read_sql(query,connection)
print(output.shape)
output
# Out:
# (10, 5)
#   customer_id       customer_name             city           state  \
# 0    AA-10480        Andrew Allen          Concord  North Carolina
# 1    AG-10270     Alejandro Grove      West Jordan            Utah
# 2    BH-11710     Brosina Hoffman      Los Angeles      California
# 3    CG-12520         Claire Gute        Henderson        Kentucky
# 4    DV-13045     Darrin Van Huff      Los Angeles      California
# 5    HP-14815       Harold Pawlan       Fort Worth           Texas
# 6    IM-15070        Irene Maddox          Seattle      Washington
# 7    PK-19075           Pete Kriz          Madison       Wisconsin
# 8    SO-20335      Sean O'Donnell  Fort Lauderdale         Florida
# 9    ZD-21925  Zuschuss Donatelli    San Francisco      California
#
#    postal_code
# 0        28027
# 1        84084
# 2        90032
# 3        42420
# 4        90036
# 5        76106
# 6        98103
# 7        53711
# 8        33311
# 9        94109

# %%
query = "select * from products " # SQL statement
output = pd.read_sql(query,connection)
print(output.shape)
output
# Out:
# (14, 4)
#          product_id         category sub_category  \
# 0   FUR-BO-10001798        Furniture    Bookcases
# 1   FUR-CH-10000454        Furniture       Chairs
# 2   FUR-FU-10001487        Furniture  Furnishings
# 3   FUR-TA-10000577        Furniture       Tables
# 4   FUR-TA-10001539        Furniture       Tables
# 5   OFF-AP-10002892  Office Supplies   Appliances
# 6   OFF-AR-10002833  Office Supplies          Art
# 7   OFF-BI-10003656  Office Supplies      Binders
# 8   OFF-BI-10003910  Office Supplies      Binders
# 9   OFF-LA-10000240  Office Supplies       Labels
# 10  OFF-PA-10002365  Office Supplies        Paper
# 11  OFF-ST-10000760  Office Supplies      Storage
# 12  TEC-PH-10002033       Technology       Phones
# 13  TEC-PH-10002275       Technology       Phones
#
#                                          product_name
# 0                   Bush Somerset Collection Bookcase
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2   Eldon Expressions Wood and Plastic Desk Access...
# 3       Bretford CR4500 Series Slim Rectangular Table
# 4            Chromcraft Rectangular Conference Tables
# 5                    Belkin F5C206VTEL 6 Outlet Surge
# 6                                          Newell 322
# 7         Fellowes PB200 Plastic Comb Binding Machine
# 8   DXL Angle-View Binders with Locking Rings by S...
# 9   Self-Adhesive Address Labels for Typewriters b...
# 10                                         Xerox 1967
# 11                     Eldon Fold 'N Roll Cart System
# 12    Konftel 250 ConferenceÂ phoneÂ - Charcoal black
# 13                     Mitel 5320 IP Phone VoIP phone

# %%
customer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 customer
#
# NameError: name 'customer' is not defined

# %%
query = "select * from orders " # SQL statement
output = pd.read_sql(query,connection)
print(output.shape)
output
# Out:
# (9, 6)
#          order_id  order_date customer_id       product_id   sales  quantity
# 0  CA-2015-115812    6/9/2015    BH-11710  FUR-FU-10001487  48.860         7
# 1  CA-2017-105654  12/10/2017    BH-11710  FUR-TA-10000577  71.530         3
# 2  CA-2017-138688   6/12/2017    DV-13045  OFF-LA-10000240  14.620         2
# 3  CA-2017-152156   11/8/2017    CG-12520  FUR-BO-10001798  58.960         2
# 4  CA-2018-109265    2/8/2018    BH-11710  OFF-LA-10000240  14.620         5
# 5  CA-2018-109862    4/9/2018    DV-13045  OFF-PA-10002365  15.552         1
# 6  CA-2018-112417    6/8/2018    SO-20335  OFF-PA-10002365  15.552         2
# 7  CA-2018-114412   4/11/2018    AA-10480  OFF-PA-10002365  15.552         3
# 8  US-2016-108966  10/11/2017    SO-20335  FUR-TA-10000577  69.650         5

# %%
# fechting only customers details who have orders
query = "select * from customers  inner join orders on orders.customer_id=customers.customer_id"
data = pd.read_sql(query,connection)
print(data.shape)
data
# Out:
# (9, 11)
#   customer_id    customer_name             city           state  postal_code  \
# 0    BH-11710  Brosina Hoffman      Los Angeles      California        90032
# 1    BH-11710  Brosina Hoffman      Los Angeles      California        90032
# 2    DV-13045  Darrin Van Huff      Los Angeles      California        90036
# 3    CG-12520      Claire Gute        Henderson        Kentucky        42420
# 4    BH-11710  Brosina Hoffman      Los Angeles      California        90032
# 5    DV-13045  Darrin Van Huff      Los Angeles      California        90036
# 6    SO-20335   Sean O'Donnell  Fort Lauderdale         Florida        33311
# 7    AA-10480     Andrew Allen          Concord  North Carolina        28027
# 8    SO-20335   Sean O'Donnell  Fort Lauderdale         Florida        33311
#
#          order_id  order_date customer_id       product_id   sales  quantity
# 0  CA-2015-115812    6/9/2015    BH-11710  FUR-FU-10001487  48.860         7
# 1  CA-2017-105654  12/10/2017    BH-11710  FUR-TA-10000577  71.530         3
# 2  CA-2017-138688   6/12/2017    DV-13045  OFF-LA-10000240  14.620         2
# 3  CA-2017-152156   11/8/2017    CG-12520  FUR-BO-10001798  58.960         2
# 4  CA-2018-109265    2/8/2018    BH-11710  OFF-LA-10000240  14.620         5
# 5  CA-2018-109862    4/9/2018    DV-13045  OFF-PA-10002365  15.552         1
# 6  CA-2018-112417    6/8/2018    SO-20335  OFF-PA-10002365  15.552         2
# 7  CA-2018-114412   4/11/2018    AA-10480  OFF-PA-10002365  15.552         3
# 8  US-2016-108966  10/11/2017    SO-20335  FUR-TA-10000577  69.650         5

# %% [markdown]
# #  Join multiple tables

# %%
# Details of products a particular customer bought
query = "select * from orders  \
left join customers on orders.customer_id=customers.customer_id \
left join products  on orders.product_id = products.product_id"
data = pd.read_sql(query,connection)
print(data.shape)
data
# Out:
# (9, 15)
#          order_id  order_date customer_id       product_id   sales  quantity  \
# 0  CA-2015-115812    6/9/2015    BH-11710  FUR-FU-10001487  48.860         7
# 1  CA-2017-105654  12/10/2017    BH-11710  FUR-TA-10000577  71.530         3
# 2  CA-2017-138688   6/12/2017    DV-13045  OFF-LA-10000240  14.620         2
# 3  CA-2017-152156   11/8/2017    CG-12520  FUR-BO-10001798  58.960         2
# 4  CA-2018-109265    2/8/2018    BH-11710  OFF-LA-10000240  14.620         5
# 5  CA-2018-109862    4/9/2018    DV-13045  OFF-PA-10002365  15.552         1
# 6  CA-2018-112417    6/8/2018    SO-20335  OFF-PA-10002365  15.552         2
# 7  CA-2018-114412   4/11/2018    AA-10480  OFF-PA-10002365  15.552         3
# 8  US-2016-108966  10/11/2017    SO-20335  FUR-TA-10000577  69.650         5
#
#   customer_id    customer_name             city           state  postal_code  \
# 0    BH-11710  Brosina Hoffman      Los Angeles      California        90032
# 1    BH-11710  Brosina Hoffman      Los Angeles      California        90032
# 2    DV-13045  Darrin Van Huff      Los Angeles      California        90036
# 3    CG-12520      Claire Gute        Henderson        Kentucky        42420
# 4    BH-11710  Brosina Hoffman      Los Angeles      California        90032
# 5    DV-13045  Darrin Van Huff      Los Angeles      California        90036
# 6    SO-20335   Sean O'Donnell  Fort Lauderdale         Florida        33311
# 7    AA-10480     Andrew Allen          Concord  North Carolina        28027
# 8    SO-20335   Sean O'Donnell  Fort Lauderdale         Florida        33311
#
#         product_id         category sub_category  \
# 0  FUR-FU-10001487        Furniture  Furnishings
# 1  FUR-TA-10000577        Furniture       Tables
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-BO-10001798        Furniture    Bookcases
# 4  OFF-LA-10000240  Office Supplies       Labels
# 5  OFF-PA-10002365  Office Supplies        Paper
# 6  OFF-PA-10002365  Office Supplies        Paper
# 7  OFF-PA-10002365  Office Supplies        Paper
# 8  FUR-TA-10000577        Furniture       Tables
#
#                                         product_name
# 0  Eldon Expressions Wood and Plastic Desk Access...
# 1      Bretford CR4500 Series Slim Rectangular Table
# 2  Self-Adhesive Address Labels for Typewriters b...
# 3                  Bush Somerset Collection Bookcase
# 4  Self-Adhesive Address Labels for Typewriters b...
# 5                                         Xerox 1967
# 6                                         Xerox 1967
# 7                                         Xerox 1967
# 8      Bretford CR4500 Series Slim Rectangular Table

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Quick Assessment

# %% [raw]
# Fetch Orders information of the customers from the California State.

# %%
query = "select customer_id,state from customers where state='California' "
customers = pd.read_sql(query,connection)
print(customers.shape)
customers
# Out:
# (3, 2)
#   customer_id       state
# 0    BH-11710  California
# 1    DV-13045  California
# 2    ZD-21925  California

# %%
query = "select * from orders where customer_id in (select customer_id from customers where state='California' )" # SQL statement
orders = pd.read_sql(query,connection)
print(orders.shape)
orders
# Out:
# (5, 6)
#          order_id  order_date customer_id       product_id   sales  quantity
# 0  CA-2015-115812    6/9/2015    BH-11710  FUR-FU-10001487  48.860         7
# 1  CA-2017-105654  12/10/2017    BH-11710  FUR-TA-10000577  71.530         3
# 2  CA-2017-138688   6/12/2017    DV-13045  OFF-LA-10000240  14.620         2
# 3  CA-2018-109265    2/8/2018    BH-11710  OFF-LA-10000240  14.620         5
# 4  CA-2018-109862    4/9/2018    DV-13045  OFF-PA-10002365  15.552         1

# %% [raw]
# Fetch Orders information of customers from california who ordered furnitures.

# %%
query = "select order_id,order_date,orders.customer_id,orders.product_id,sales,quantity from orders  \
inner join customers on orders.customer_id=customers.customer_id \
inner join products  on orders.product_id = products.product_id where  products.category='Furniture' and customers.state='California' "
data = pd.read_sql(query,connection)
print(data.shape)
data
# Out:
# (2, 6)
#          order_id  order_date customer_id       product_id  sales  quantity
# 0  CA-2015-115812    6/9/2015    BH-11710  FUR-FU-10001487  48.86         7
# 1  CA-2017-105654  12/10/2017    BH-11710  FUR-TA-10000577  71.53         3

# %% [markdown]
# # Saving database tables in your system

# %%
output.to_csv('customers.csv')

# %%
df=pd.read_csv('customers.csv')
df
# Out:
#    Unnamed: 0        order_id  order_date customer_id       product_id  \
# 0           0  CA-2015-115812    6/9/2015    BH-11710  FUR-FU-10001487
# 1           1  CA-2017-105654  12/10/2017    BH-11710  FUR-TA-10000577
# 2           2  CA-2017-138688   6/12/2017    DV-13045  OFF-LA-10000240
# 3           3  CA-2017-152156   11/8/2017    CG-12520  FUR-BO-10001798
# 4           4  CA-2018-109265    2/8/2018    BH-11710  OFF-LA-10000240
# 5           5  CA-2018-109862    4/9/2018    DV-13045  OFF-PA-10002365
# 6           6  CA-2018-112417    6/8/2018    SO-20335  OFF-PA-10002365
# 7           7  CA-2018-114412   4/11/2018    AA-10480  OFF-PA-10002365
# 8           8  US-2016-108966  10/11/2017    SO-20335  FUR-TA-10000577
#
#     sales  quantity
# 0  48.860         7
# 1  71.530         3
# 2  14.620         2
# 3  58.960         2
# 4  14.620         5
# 5  15.552         1
# 6  15.552         2
# 7  15.552         3
# 8  69.650         5
